# %%
import pandas as pd 
import sys

# %%
data = pd.read_csv("data.csv").drop(columns=['Date / Time'])
data
# Out:
#     host#HOST1#% Free Memory avg 1 h  host#HOST2#% Free Memory avg 1 h  \
# 0                              77.89                             77.73
# 1                              77.89                             77.73
# 2                              77.88                             77.73
# 3                              77.88                             77.73
# 4                              77.88                             77.72
# 5                              77.87                             77.72
# 6                              77.87                             77.72
# 7                              77.87                             77.72
# 8                              77.87                             77.72
# 9                              77.87                             77.71
# 10                             77.86                             77.71
# 11                             77.86                             77.71
# ...

# %%
data.describe()
# Out:
#        host#HOST1#% Free Memory avg 1 h  host#HOST2#% Free Memory avg 1 h  \
# count                          24.00000                         24.000000
# mean                           77.86250                         77.708333
# std                             0.01391                          0.014646
# min                            77.85000                         77.690000
# 25%                            77.85000                         77.697500
# 50%                            77.86000                         77.710000
# 75%                            77.87000                         77.720000
# max                            77.89000                         77.730000
#
#        host#HOST3#% Free Memory avg 1 h  host#HOST4#% Free Memory avg 1 h  \
# count                         24.000000                         24.000000
# mean                          77.774167                         78.045000
# std                            0.009743                          0.010215
# ...

# %%
min_per_host = data.min()

# %%
min_per_host_min = min_per_host.min()

# %%
min_per_host_max = min_per_host.max()

# %%
min_per_host_mean = min_per_host.mean()

# %%
max_per_host = data.max()

# %%
max_per_host_min = max_per_host.min()

# %%
max_per_host_max = max_per_host.max()

# %%
max_per_host_mean = max_per_host.mean()

# %%
mean_per_host = data.mean()

# %%
mean_per_host_min = mean_per_host.min()

# %%
mean_per_host_max = mean_per_host.max()

# %%
mean_per_host_mean = mean_per_host.mean()

# %% [markdown]
# Minimum Value For Each Hostname

# %%
sys.stdout.write(str(min_per_host))
# Out:
# host#HOST1#% Free Memory avg 1 h     77.85
# host#HOST2#% Free Memory avg 1 h     77.69
# host#HOST3#% Free Memory avg 1 h     77.75
# host#HOST4#% Free Memory avg 1 h     78.03
# host#HOST5#% Free Memory avg 1 h     85.92
# host#HOST6#% Free Memory avg 1 h     93.28
# host#HOST7#% Free Memory avg 1 h     96.50
# host#HOST8#% Free Memory avg 1 h     90.07
# host#HOST9#% Free Memory avg 1 h     96.10
# host#HOST10#% Free Memory avg 1 h    99.23
# host#HOST11#% Free Memory avg 1 h    94.84
# host#HOST12#% Free Memory avg 1 h    54.27
# host#HOST13#% Free Memory avg 1 h    39.54
# host#HOST14#% Free Memory avg 1 h    51.16
# host#HOST15#% Free Memory avg 1 h    81.26
# host#HOST16#% Free Memory avg 1 h    85.09
# host#HOST17#% Free Memory avg 1 h    60.58
# host#HOST18#% Free Memory avg 1 h    79.35
# host#HOST19#% Free Memory avg 1 h    82.42
# host#HOST20#% Free Memory avg 1 h    71.12
# host#HOST21#% Free Memory avg 1 h    54.34
# host#HOST22#% Free Memory avg 1 h    57.55
# ...

# %%
sys.stdout.write('Minimum Value of the Minimums: ' + str(min_per_host_min) + '\n' + 'Maximum Value of the Minimums: ' + str(min_per_host_max) + '\n' + 'Mean Value of the Minimums: ' + str(min_per_host_mean))
# Out:
# Minimum Value of the Minimums: 31.82
# Maximum Value of the Minimums: 99.23
# Mean Value of the Minimums: 67.09206896551724

# %% [markdown]
# Maximum Value of Each Hostname

# %%
sys.stdout.write(str(max_per_host))
# Out:
# host#HOST1#% Free Memory avg 1 h     77.89
# host#HOST2#% Free Memory avg 1 h     77.73
# host#HOST3#% Free Memory avg 1 h     77.79
# host#HOST4#% Free Memory avg 1 h     78.06
# host#HOST5#% Free Memory avg 1 h     87.47
# host#HOST6#% Free Memory avg 1 h     93.64
# host#HOST7#% Free Memory avg 1 h     96.83
# host#HOST8#% Free Memory avg 1 h     92.09
# host#HOST9#% Free Memory avg 1 h     96.52
# host#HOST10#% Free Memory avg 1 h    99.57
# host#HOST11#% Free Memory avg 1 h    94.98
# host#HOST12#% Free Memory avg 1 h    54.84
# host#HOST13#% Free Memory avg 1 h    40.80
# host#HOST14#% Free Memory avg 1 h    51.38
# host#HOST15#% Free Memory avg 1 h    81.30
# host#HOST16#% Free Memory avg 1 h    93.46
# host#HOST17#% Free Memory avg 1 h    61.20
# host#HOST18#% Free Memory avg 1 h    97.42
# host#HOST19#% Free Memory avg 1 h    83.14
# host#HOST20#% Free Memory avg 1 h    73.03
# host#HOST21#% Free Memory avg 1 h    61.11
# host#HOST22#% Free Memory avg 1 h    61.31
# ...

# %%
sys.stdout.write('Minimum Value of the Maximums: ' + str(max_per_host_min) + '\n' + 'Maximum Value of the Maximums: ' + str(max_per_host_max) + '\n' + 'Mean Value of the Maximums: ' + str(max_per_host_mean))
# Out:
# Minimum Value of the Maximums: 40.69
# Maximum Value of the Maximums: 99.57
# Mean Value of the Maximums: 70.4796551724138

# %% [markdown]
# Mean Value of Each Hostname

# %%
sys.stdout.write(str(mean_per_host))
# Out:
# host#HOST1#% Free Memory avg 1 h     77.862500
# host#HOST2#% Free Memory avg 1 h     77.708333
# host#HOST3#% Free Memory avg 1 h     77.774167
# host#HOST4#% Free Memory avg 1 h     78.045000
# host#HOST5#% Free Memory avg 1 h     86.842500
# host#HOST6#% Free Memory avg 1 h     93.495000
# host#HOST7#% Free Memory avg 1 h     96.682917
# host#HOST8#% Free Memory avg 1 h     90.807917
# host#HOST9#% Free Memory avg 1 h     96.349130
# host#HOST10#% Free Memory avg 1 h    99.404000
# host#HOST11#% Free Memory avg 1 h    94.901250
# host#HOST12#% Free Memory avg 1 h    54.766250
# host#HOST13#% Free Memory avg 1 h    40.522917
# host#HOST14#% Free Memory avg 1 h    51.274167
# host#HOST15#% Free Memory avg 1 h    81.288750
# host#HOST16#% Free Memory avg 1 h    92.102500
# host#HOST17#% Free Memory avg 1 h    61.169583
# host#HOST18#% Free Memory avg 1 h    82.982917
# host#HOST19#% Free Memory avg 1 h    82.770833
# host#HOST20#% Free Memory avg 1 h    71.924167
# ...

# %%
sys.stdout.write('Minimum Value of the Means: ' + str(mean_per_host_min) + '\n' + 'Maximum Value of the Means: ' + str(mean_per_host_max) + '\n' + 'Mean Value of the Means: ' + str(mean_per_host_mean))
# Out:
# Minimum Value of the Means: 36.36545454545455
# Maximum Value of the Means: 99.40400000000001
# Mean Value of the Means: 68.54660350506565
